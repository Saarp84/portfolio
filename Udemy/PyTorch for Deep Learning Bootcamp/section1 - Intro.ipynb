# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import mysql.connector
from sqlalchemy import create_engine

nba_df = pd.read_csv(r"C:\Users\saarp\Desktop\sql\database_24_25.csv")
veterans = pd.read_csv(r"C:\Users\saarp\Desktop\sql\all_seasons.csv")

conn = mysql.connector.connect(
    host="localhost", 
    user="root",  
    password="4362",  
    database="test_db"
)
cursor = conn.cursor()

conn2 = mysql.connector.connect(
    host="localhost", 
    user="root",  
    password="4362",  
    database="sakila"
)
cursor2 = conn2.cursor()

conn3 = mysql.connector.connect(
    host="localhost", 
    user="root",  
    password="4362",  
    database="world"
)
cursor3 = conn3.cursor()
